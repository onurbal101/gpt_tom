# %% [markdown]
# ## Imports
#
# Importing the required modules for the project.

# %% [markdown]
# Pandas is used for its advanced dataframe functionality.

# %%
import pandas as pd

# %% [markdown]
# ## Processing the Input
#
# We will work with the file called `parameters.xlsx`, which contains the parameters to be used for our study. We will merge the different sheets inside of it in order to produce a combined Excel file, which will be used in `get_responses.ipynb` to run our trials and get responses from the OpenAI API.

# %% [markdown]
# Reading in the initial Excel sheet.

# %%
excel_sheets = pd.read_excel(
    "../input/parameters/01_parameters.xlsx",
    sheet_name=None
    )

# %%
for sheet_name, df in excel_sheets.items():
    print(sheet_name)
    display(df.head(3))
# Out:
# tbl_studies
#    study_id          study_name
# 0         1  Ullman Replication
# 1         2    Ullman Expansion
# 2         3        Second Order
# tbl_scenarios
#    scenario_id scenario_code  study_id story_id  chat_id
# 0            1        1-EN/1         1     1-EN        1
# 1            2       1A-EN/1         1    1A-EN        1
# 2            3      1B-EN/66         1    1B-EN       66
# tbl_system_messages
#    system_message_id  study_id system_message_language  \
# 0                  1         1                 English
# 1                  2         1                 Turkish
# 2                  3         2                 English
#
#          system_message_content
# 0  You are a helpful assistant.
# 1   Yardımsever bir asistansın.
# 2  You are a helpful assistant.
# tbl_stories
#   story_id story_common_id       story_category   story_name  \
# 0     1-EN               1  Unexpected Contents       Base 1
# 1     1-TR               1  Unexpected Contents       Base 1
# 2    1A-EN              1A  Unexpected Contents  Transparent
#
#                                        story_content story_language
# 0  Here is a bag filled with popcorn. There is no...        English
# 1  İçi patlamış mısır dolu bir poşet var. Poşetin...        Turkish
# 2  Here is a bag filled with popcorn. There is no...        English
# tbl_chats
#    chat_id                                          chat_name chat_language  \
# 0        1       Ullman Replication: Universal 1 Q1 (English)       English
# 1        2       Ullman Replication: Universal 1 Q1 (Turkish)       Turkish
# 2        3  Ullman Replication: Universal 1 Q1 (Turkish, F...       Turkish
#
#    chat_has_fbv_zan  chat_has_fbv_san questions
# 0               NaN               NaN      1_EN
# 1               NaN               NaN    1_TR-1
# 2               1.0               NaN    1_TR-2
# tbl_questions
#   question_id  question_common_id  \
# 0        1_EN                   1
# 1     1_EN/1B                   1
# 2      1_TR-1                   1
#
#                                    question_content  \
# 0  She believes that the bag is full of {RESPONSE}.
# 1  She believes that the bag is full of {RESPONSE}.
# 2     Ezgi torbanın {CEVAP} dolu olduğuna inanıyor.
#
#                   question_options question_type question_language  \
# 0               popcorn, chocolate  Closed-ended           English
# 1  popcorn, chocolate, uncertainty  Closed-ended           English
# 2         patlamış mısır, çikolata  Closed-ended           Turkish
#
#    question_has_fbv_zan  question_has_fbv_san  question_tom_order  \
# 0                   NaN                   NaN                   1
# 1                   NaN                   NaN                   1
# 2                   NaN                   NaN                   1
#
#   question_tom_type
# 0            Belief
# 1            Belief
# 2            Belief
# tbl_answers
#    answer_id story_id question_id  \
# 0          1     1-EN        1_EN
# 1          2     1-EN        2_EN
# 2          3     1-EN        3_EN
#
#                                       answer_correct
# 0                                          chocolate
# 1                                          chocolate
# 2  Because the label says there is chocolate in t...

# %% [markdown]
# Combining the different tables present in the Excel file using the primary and foreign keys.

# %%
merge_map = [
    {
        "left": "tbl_studies",
        "right": "tbl_scenarios",
        "on": "study_id"
    },

    {
        "right": "tbl_stories",
        "on": "story_id"
    },

    {
        "right": "tbl_chats",
        "on": "chat_id"
    },

    {
        "right": "tbl_system_messages",
        "left_on": ["study_id", "chat_language"],
        "right_on": ["study_id", "system_message_language"]
    }
]

# %%
def merge_sheets(excel_sheets, merge_map: list[dict[str, any]]):
    previous_df = None

    for map in merge_map:
        left_df = None
        if "left" in map:
            left_df = excel_sheets[map["left"]]
            left_suffix = f"_{map["left"].split("_")[-1]}"
        else:
            left_df = previous_df
            left_suffix = f"{left_suffix}{right_suffix}"

        right_df = excel_sheets[map["right"]]
        right_suffix = f"_{map["right"].split("_")[-1]}"

        if "on" in map:
            combined_df = pd.merge(
                left_df,
                right_df,
                how="left",
                on=map["on"],
                suffixes=(left_suffix, right_suffix)
            )
        elif "left_on" in map and "right_on" in map:
            combined_df = pd.merge(
                left_df,
                right_df,
                how="left",
                left_on=map["left_on"],
                right_on=map["right_on"],
                suffixes=(left_suffix, right_suffix)
            )
        
        previous_df = combined_df
    
    return previous_df

# %%
combined_df = merge_sheets(excel_sheets, merge_map)

# %%
combined_df = pd.merge(
    excel_sheets["tbl_studies"],
    excel_sheets["tbl_scenarios"],
    how="left",
    on="study_id",
    suffixes=("_studies", "_scenarios")
    )

combined_df = pd.merge(
    combined_df,
    excel_sheets["tbl_stories"],
    how="left",
    on="story_id",
    suffixes=("_studies_scenarios", "_stories")
)

combined_df = pd.merge(
    combined_df,
    excel_sheets["tbl_chats"],
    how="left",
    on="chat_id",
    suffixes=("_studies_scenarios_stories", "_chats")
)

combined_df = pd.merge(
    combined_df,
    excel_sheets["tbl_system_messages"],
    how="left",
    left_on=["study_id", "chat_language"],
    right_on=["study_id", "system_message_language"],
    suffixes=("_studies_scenarios_stories_chats", "_system_messages")
)

# %% [markdown]
# Let us have a look at the combined dataframe's properties.

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   study_id                 116 non-null    int64
#  1   study_name               116 non-null    object
#  2   scenario_id              116 non-null    int64
#  3   scenario_code            116 non-null    object
#  4   story_id                 116 non-null    object
#  5   chat_id                  116 non-null    int64
#  6   story_common_id          116 non-null    object
#  7   story_category           116 non-null    object
#  8   story_name               116 non-null    object
#  9   story_content            116 non-null    object
#  10  story_language           116 non-null    object
#  11  chat_name                116 non-null    object
#  12  chat_language            116 non-null    object
#  13  chat_has_fbv_zan         24 non-null     float64
#  14  chat_has_fbv_san         24 non-null     float64
#  15  questions                116 non-null    object
#  16  system_message_id        116 non-null    int64
#  17  system_message_language  116 non-null    object
#  18  system_message_content   116 non-null    object
# dtypes: float64(2), int64(4), object(13)
# memory usage: 17.3+ KB

# %% [markdown]
# Let us preview the first 3 rows of our dataframe.

# %%
combined_df.head(3)
# Out:
#    study_id          study_name  scenario_id scenario_code story_id  chat_id  \
# 0         1  Ullman Replication            1        1-EN/1     1-EN        1
# 1         1  Ullman Replication            2       1A-EN/1    1A-EN        1
# 2         1  Ullman Replication            3      1B-EN/66    1B-EN       66
#
#   story_common_id       story_category     story_name  \
# 0               1  Unexpected Contents         Base 1
# 1              1A  Unexpected Contents    Transparent
# 2              1B  Unexpected Contents  Uninformative
#
#                                        story_content story_language  \
# 0  Here is a bag filled with popcorn. There is no...        English
# 1  Here is a bag filled with popcorn. There is no...        English
# 2  Here is a bag filled with popcorn. There is no...        English
#
#                                       chat_name chat_language  \
# 0  Ullman Replication: Universal 1 Q1 (English)       English
# 1  Ullman Replication: Universal 1 Q1 (English)       English
# 2           Ullman Replication: 1B Q1 (English)       English
#
#    chat_has_fbv_zan  chat_has_fbv_san questions  system_message_id  \
# 0               NaN               NaN      1_EN                  1
# 1               NaN               NaN      1_EN                  1
# 2               NaN               NaN   1_EN/1B                  1
#
#   system_message_language        system_message_content
# 0                 English  You are a helpful assistant.
# 1                 English  You are a helpful assistant.
# 2                 English  You are a helpful assistant.

# %% [markdown]
# Right now, each row in our dataframe represents a scenario. The questions to be asked in each scenario can be found in the `questions` column. This column is currently of the type `string`. More specifically, it's a list of comma separated values.
#
# What we want to do now is split them into a list, and expand our dataframe so that each row represent a question to be asked in a given scenario.

# %% [markdown]
# Splitting the questions.

# %%
def split_into_columns(series: pd.Series):
    series.str.split(", ", expand=True)

# %%
questions_expanded = combined_df["questions"].str.split(", ", expand=True)

# %%
questions_expanded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       116 non-null    object
#  1   1       56 non-null     object
#  2   2       56 non-null     object
#  3   3       56 non-null     object
#  4   4       16 non-null     object
#  5   5       16 non-null     object
#  6   6       8 non-null      object
#  7   7       4 non-null      object
# dtypes: object(8)
# memory usage: 7.4+ KB

# %%
questions_expanded.head(3)
# Out:
#          0     1     2     3     4     5     6     7
# 0     1_EN  None  None  None  None  None  None  None
# 1     1_EN  None  None  None  None  None  None  None
# 2  1_EN/1B  None  None  None  None  None  None  None

# %%
combined_df = pd.melt(
    pd.concat(
        [combined_df, questions_expanded],
        axis=1
        ),
        id_vars=combined_df.columns,
        value_vars=questions_expanded.columns,
        var_name="question_index",
        value_name="question_id"
        )

# %%
combined_df = pd.merge(
    combined_df,
    excel_sheets["tbl_questions"],
    on="question_id").dropna(subset=["question_id", "question_content"])

# %%
combined_df = pd.merge(
    combined_df,
    excel_sheets["tbl_answers"],
    how="left",
    on=["story_id", "question_id"],
    suffixes=("_studies_scenarios_stories_chats_messages", "_system_messages")
)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   study_id                 327 non-null    int64
#  1   study_name               327 non-null    object
#  2   scenario_id              327 non-null    int64
#  3   scenario_code            327 non-null    object
#  4   story_id                 327 non-null    object
#  5   chat_id                  327 non-null    int64
#  6   story_common_id          327 non-null    object
#  7   story_category           327 non-null    object
#  8   story_name               327 non-null    object
#  9   story_content            327 non-null    object
#  10  story_language           327 non-null    object
#  11  chat_name                327 non-null    object
#  12  chat_language            327 non-null    object
#  13  chat_has_fbv_zan         77 non-null     float64
#  14  chat_has_fbv_san         76 non-null     float64
#  15  questions                327 non-null    object
#  16  system_message_id        327 non-null    int64
#  17  system_message_language  327 non-null    object
#  18  system_message_content   327 non-null    object
#  19  question_index           327 non-null    object
#  20  question_id              327 non-null    object
#  21  question_common_id       327 non-null    int64
#  22  question_content         327 non-null    object
#  23  question_options         271 non-null    object
#  24  question_type            327 non-null    object
#  25  question_language        327 non-null    object
#  26  question_has_fbv_zan     41 non-null     float64
#  27  question_has_fbv_san     41 non-null     float64
#  28  question_tom_order       327 non-null    int64
#  29  question_tom_type        327 non-null    object
#  30  answer_id                327 non-null    int64
#  31  answer_correct           327 non-null    object
# dtypes: float64(4), int64(7), object(21)
# memory usage: 81.9+ KB

# %%
combined_df.columns
# Out:
# Index(['study_id', 'study_name', 'scenario_id', 'scenario_code', 'story_id',
#        'chat_id', 'story_common_id', 'story_category', 'story_name',
#        'story_content', 'story_language', 'chat_name', 'chat_language',
#        'chat_has_fbv_zan', 'chat_has_fbv_san', 'questions',
#        'system_message_id', 'system_message_language',
#        'system_message_content', 'question_index', 'question_id',
#        'question_common_id', 'question_content', 'question_options',
#        'question_type', 'question_language', 'question_has_fbv_zan',
#        'question_has_fbv_san', 'question_tom_order', 'question_tom_type',
#        'answer_id', 'answer_correct'],
#       dtype='object')

# %% [markdown]
# Now, the amount of rows represents the amount of questions to be asked.

# %%
combined_df = combined_df.sort_values(
    by=["study_id", "scenario_id", "chat_id", "question_index"]
    )

# %%
combined_df.head(3)
# Out:
#    study_id          study_name  scenario_id scenario_code story_id  chat_id  \
# 0         1  Ullman Replication            1        1-EN/1     1-EN        1
# 1         1  Ullman Replication            2       1A-EN/1    1A-EN        1
# 8         1  Ullman Replication            3      1B-EN/66    1B-EN       66
#
#   story_common_id       story_category     story_name  \
# 0               1  Unexpected Contents         Base 1
# 1              1A  Unexpected Contents    Transparent
# 8              1B  Unexpected Contents  Uninformative
#
#                                        story_content  ...  \
# 0  Here is a bag filled with popcorn. There is no...  ...
# 1  Here is a bag filled with popcorn. There is no...  ...
# 8  Here is a bag filled with popcorn. There is no...  ...
#
#                                    question_content  \
# 0  She believes that the bag is full of {RESPONSE}.
# 1  She believes that the bag is full of {RESPONSE}.
# 8  She believes that the bag is full of {RESPONSE}.
#
#                   question_options question_type  question_language  \
# 0               popcorn, chocolate  Closed-ended            English
# 1               popcorn, chocolate  Closed-ended            English
# 8  popcorn, chocolate, uncertainty  Closed-ended            English
#
#    question_has_fbv_zan question_has_fbv_san  question_tom_order  \
# 0                   NaN                  NaN                   1
# 1                   NaN                  NaN                   1
# 8                   NaN                  NaN                   1
#
#   question_tom_type answer_id answer_correct
# 0            Belief         1      chocolate
# 1            Belief        11        popcorn
# 8            Belief        21    uncertainty
#
# [3 rows x 32 columns]

# %%
combined_df[combined_df["scenario_id"] == 61]
# Out:
#      study_id        study_name  scenario_id scenario_code story_id  chat_id  \
# 24          2  Ullman Expansion           61       1-TR/23     1-TR       23
# 48          2  Ullman Expansion           61       1-TR/23     1-TR       23
# 182         2  Ullman Expansion           61       1-TR/23     1-TR       23
# 238         2  Ullman Expansion           61       1-TR/23     1-TR       23
#
#     story_common_id       story_category story_name  \
# 24                1  Unexpected Contents     Base 1
# 48                1  Unexpected Contents     Base 1
# 182               1  Unexpected Contents     Base 1
# 238               1  Unexpected Contents     Base 1
#
#                                          story_content  ...  \
# 24   İçi patlamış mısır dolu bir poşet var. Poşetin...  ...
# 48   İçi patlamış mısır dolu bir poşet var. Poşetin...  ...
# 182  İçi patlamış mısır dolu bir poşet var. Poşetin...  ...
# 238  İçi patlamış mısır dolu bir poşet var. Poşetin...  ...
#
#                                       question_content  \
# 24     Ezgi torbanın {CEVAP} dolu olduğunu zannediyor.
# 48   Ezgi bu torbayı bulduğu için çok mutlu. O {CEV...
# 182  Poşetin neden o malzemeyle dolu olduğunu zanne...
# 238  Ezgi torbayı açar ve içine bakar. Ezgi açık bi...
#
#              question_options question_type  question_language  \
# 24   patlamış mısır, çikolata  Closed-ended            Turkish
# 48   patlamış mısır, çikolata  Closed-ended            Turkish
# 182                       NaN    Open-ended            Turkish
# 238  patlamış mısır, çikolata  Closed-ended            Turkish
#
#      question_has_fbv_zan question_has_fbv_san  question_tom_order  \
# 24                    1.0                  NaN                   1
# 48                    NaN                  NaN                   1
# 182                   1.0                  NaN                   1
# 238                   NaN                  NaN                   0
#
#     question_tom_type answer_id  \
# 24             Belief         6
# 48             Action         7
# 182       Explanation         9
# 238           Reality        10
#
#                                         answer_correct
# 24                                            çikolata
# 48                                            çikolata
# 182  Çünkü etikette poşetin içerisinde çikolata old...
# 238                                     patlamış mısır
#
# [4 rows x 32 columns]

# %%
combined_df[combined_df["scenario_id"] == 31]
# Out:
#     study_id          study_name  scenario_id scenario_code story_id  chat_id  \
# 65         1  Ullman Replication           31       2C-TR/7    2C-TR        7
#
#    story_common_id       story_category     story_name  \
# 65              2C  Unexpected Transfer  Communication
#
#                                         story_content  ...  \
# 65  Odada Can, Mehmet, bir kedi, bir kutu, ve bir ...  ...
#
#                                   question_content  question_options  \
# 65  Can kedinin {CEVAP} içinde olduğunu düşünüyor.  kutunun, sepetin
#
#    question_type  question_language  question_has_fbv_zan  \
# 65  Closed-ended            Turkish                   NaN
#
#    question_has_fbv_san  question_tom_order question_tom_type answer_id  \
# 65                  NaN                   1           Thought        82
#
#    answer_correct
# 65        kutunun
#
# [1 rows x 32 columns]

# %% [markdown]
# We will now save it to a `.csv` file, which will be used to get the desired responses from the OpenAI API.

# %%
combined_df.to_csv("../input/parameters_expanded/03_parameters_expanded.csv")
