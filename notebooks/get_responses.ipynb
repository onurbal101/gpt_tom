# %% [markdown]
# ## Imports
#
# Importing the required modules for the project.

# %% [markdown]
# OpenAI API for interacting with ChatGPT.

# %%
from openai import OpenAI

# %% [markdown]
# The ```dotenv_values``` function from the dotenv module for accessing configuration file properties.

# %%
from dotenv import dotenv_values

# %% [markdown]
# Numpy and Pandas for advanced array and dataframe functionality, respectively.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Global Settings
#
# Global settings and variables to be used throughout the project.

# %% [markdown]
# Creating the OpenAI client and setting the OpenAI API key.
#
# **NOTE:** You should have your key stored in a file named `.env` inside the parent folder of this notebook.
#
# In this file, you need to store your key as such:
#
# `OPENAI_API_KEY={YOUR_API_KEY}`

# %%
openai_client = OpenAI(api_key=dotenv_values("../../.env")["OPENAI_API_KEY"])

# %% [markdown]
# Defining a random number generator to be used throughout the project in order to ensure the same random results are obtained each time the project is run.

# %%
rng = np.random.default_rng(seed=101)

# %% [markdown]
# ## Function Definitions
#
# Defining the public and private functions to be used.

# %% [markdown]
# ### Private Functions
#
# These are private, helper functions. They are not meant to be used on their own, and are instead called by the main functions to be utilised by the user.

# %%
def document_class_instance(instance: any) -> None:
    print(f"\tInstance Class: {type(instance)}\n")
    for key, value in vars(instance).items():
        print(f"{key} (type: {type(value)}):\n\t{value}\n")

# %%
def create_initial_messages(system_message: str) -> list[dict[str, str]]:
    messages: list[dict[str, str]] = [
        
        {
            "role": "system",
            "content": system_message
        }

    ]

    return messages

# %% [markdown]
# ### Public Functions
#
# The below are the public functions to be used in this project.

# %%
def get_chatgpt_response(
        *args, 
        messages: list[dict[str, str]],
        engine: str = "gpt-3.5-turbo",
        max_tokens: int = 500,
        temperature: float = 0.0,
        n: int = 1,
        **kwargs
        ):

    response = openai_client.chat.completions.create(
        messages=messages,
        model=engine,
        max_tokens=max_tokens,
        temperature=temperature,
        n=n,
        seed=42
    )

    return response

# %%
def get_chatgpt_responses(
        *args,
        system_message: str,
        prompts: list[str],
        engine: str = "gpt-3.5-turbo",
        max_tokens: int = 500,
        temperature: float = 0.0,
        n: int = 1,
        **kwargs
):
    
    if len(prompts) > 1:
        n = 1

    chat: dict[str, list] = {
        "messages": create_initial_messages(system_message),
        "responses": []
              }

    for prompt in prompts:
        
        chat["messages"].append({"role": "user", "content": prompt})

        response = get_chatgpt_response(
            messages=chat["messages"],
            engine=engine,
            max_tokens=max_tokens,
            temperature=temperature,
            n=n
            )
        
        response_message_content: str = response.choices[0].message.content

        chat["responses"].append(response)
        chat["messages"].append({"role": "assistant", "content": response_message_content})

        print(f"\tgpt: {chat["messages"][-1]["content"]}")

    return chat

# %%
def serialise(responses: list):
    cdfs = []
    for chat_completion in responses:
        chat_dict = dict(chat_completion)
        choice_dicts = []
        for choice in chat_dict["choices"]:
            choice_dict = dict(choice)
            choice_dict["message"] = dict(choice_dict["message"])
            choice_dicts.append(choice_dict)  

        chat_dict["choices"] = choice_dicts
        chat_dict["usage"] = dict(chat_dict["usage"])
        cdf = pd.json_normalize(chat_dict)

        choices_normalised_list = [pd.json_normalize(choices['message']) for choices in choice_dicts]
        cdf_normalised = pd.concat(choices_normalised_list, axis=1)

        cdf = pd.concat([cdf, cdf_normalised], axis=1).drop("choices", axis=1)

        cdf.columns = cdf.columns.str.removeprefix("usage.")

        cdfs.append(cdf)

    df = pd.concat(cdfs)
    return df

# %%
def run_scenario(
        scenario: pd.DataFrame,
        n: int = 1,
        engine: str = "gpt-3.5-turbo",
        max_tokens: int = 500,
        temperature: float = 0.0
        ):
    
    system_message = scenario.iloc[0]["system_message_content"]

    prompts = scenario["question_content"].to_list()
    prompts[0] = f"{scenario.iloc[0]["story_content"]}\n\n{prompts[0]}"
    
    responses = get_chatgpt_responses(
        system_message=system_message,
        prompts=prompts,
        engine=engine,
        max_tokens=max_tokens,
        temperature=temperature,
        n=n
        )
    
    return responses

# %%
def run_scenarios(scenarios: pd.DataFrame,
                  n_scenario: int = 1,
                  n_response: int = 1):
    responses_dfs = []
    for scenario_id in scenarios["scenario_id"].unique():
        scenario = scenarios[scenarios["scenario_id"] == scenario_id]
        
        responses = run_scenario(scenario, n_response)
        responses_df = serialise(responses["responses"])

        responses_dfs.append(responses_df)
    
    return pd.concat(responses_dfs)

# %% [markdown]
# ## Variable Definitions
#
# Creating the required variables for our project.

# %% [markdown]
# Creating the questions dictionary in order to test for four different variations of the question to be asked. Two of these questions are "observation" based, while the remaining two are "intervention" based.

# %% [markdown]
# ## Examples
#
# We will have a look at an example prompt and response.

# %%
df = pd.read_csv("../input/processed/combined.csv", index_col=0)

# %%
df.head(3)
# Out:
#    study_id          study_name  scenario_id scenario_code story_id  chat_id  \
# 0         1  Ullman Replication            1        1-EN/1     1-EN        1
# 1         1  Ullman Replication            2       1A-EN/1    1A-EN        1
# 2         1  Ullman Replication            3       1B-EN/1    1B-EN        1
#
#   story_common_id       story_category     story_name  \
# 0               1  Unexpected Contents         Base 1
# 1              1A  Unexpected Contents    Transparent
# 2              1B  Unexpected Contents  Uninformative
#
#                                        story_content  ... question_common_id  \
# 0  Here is a bag filled with popcorn. There is no...  ...                  1
# 1  Here is a bag filled with popcorn. There is no...  ...                  1
# 2  Here is a bag filled with popcorn. There is no...  ...                  1
#
#                                    question_content question_type  \
# 0  She believes that the bag is full of {RESPONSE}.  Closed-ended
# 1  She believes that the bag is full of {RESPONSE}.  Closed-ended
# 2  She believes that the bag is full of {RESPONSE}.  Closed-ended
#
#    question_language  question_has_fbv_zan question_has_fbv_san  \
# 0            English                   NaN                  NaN
# 1            English                   NaN                  NaN
# 2            English                   NaN                  NaN
#
#    question_tom_order question_tom_type answer_id  answer_correct
# 0                   1            Belief         1       chocolate
# 1                   1            Belief        11         popcorn
# 2                   1            Belief        21     uncertainty
#
# [3 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 328 entries, 0 to 323
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   study_id                 328 non-null    int64
#  1   study_name               328 non-null    object
#  2   scenario_id              328 non-null    int64
#  3   scenario_code            328 non-null    object
#  4   story_id                 328 non-null    object
#  5   chat_id                  328 non-null    int64
#  6   story_common_id          328 non-null    object
#  7   story_category           328 non-null    object
#  8   story_name               328 non-null    object
#  9   story_content            328 non-null    object
#  10  story_language           328 non-null    object
#  11  chat_name                328 non-null    object
#  12  chat_language            328 non-null    object
#  13  chat_has_fbv_zan         77 non-null     float64
#  14  chat_has_fbv_san         77 non-null     float64
#  15  questions                328 non-null    object
#  16  system_message_id        328 non-null    int64
#  17  system_message_language  328 non-null    object
#  18  system_message_content   328 non-null    object
#  19  question_index           328 non-null    int64
#  20  question_id              328 non-null    object
#  21  question_common_id       328 non-null    int64
#  22  question_content         328 non-null    object
#  23  question_type            328 non-null    object
#  24  question_language        328 non-null    object
#  25  question_has_fbv_zan     41 non-null     float64
#  26  question_has_fbv_san     41 non-null     float64
#  27  question_tom_order       328 non-null    int64
#  28  question_tom_type        328 non-null    object
#  29  answer_id                328 non-null    int64
#  30  answer_correct           328 non-null    object
# dtypes: float64(4), int64(8), object(19)
# memory usage: 82.0+ KB

# %%
df.describe().T
# Out:
#                       count       mean        std  min    25%   50%     75%  \
# study_id              328.0   2.146341   0.701627  1.0   2.00   2.0    3.00
# scenario_id           328.0  74.567073  27.694739  1.0  58.75  79.0   92.00
# chat_id               328.0  31.533537  15.004549  1.0  22.00  31.0   44.00
# chat_has_fbv_zan       77.0   1.000000   0.000000  1.0   1.00   1.0    1.00
# chat_has_fbv_san       77.0   1.000000   0.000000  1.0   1.00   1.0    1.00
# system_message_id     328.0   4.027439   1.494898  1.0   3.00   4.0    5.00
# question_index        328.0   1.695122   1.732503  0.0   0.00   1.0    3.00
# question_common_id    328.0  10.048780   9.689873  1.0   3.00   6.0   15.00
# question_has_fbv_zan   41.0   1.000000   0.000000  1.0   1.00   1.0    1.00
# question_has_fbv_san   41.0   1.000000   0.000000  1.0   1.00   1.0    1.00
# question_tom_order    328.0   0.841463   0.529717  0.0   1.00   1.0    1.00
# answer_id             328.0  89.432927  54.903544  1.0  44.75  83.0  138.25
#
#                         max
# study_id                3.0
# scenario_id           116.0
# chat_id                56.0
# chat_has_fbv_zan        1.0
# chat_has_fbv_san        1.0
# system_message_id       6.0
# question_index          7.0
# question_common_id     35.0
# question_has_fbv_zan    1.0
# question_has_fbv_san    1.0
# question_tom_order      2.0
# answer_id             196.0

# %%
output = []

for scenario_id in df["scenario_id"].unique():
    print(scenario_id, end=":\n")
    scenario = df[df["scenario_id"] == scenario_id].reset_index(drop=True)

    responses = run_scenario(scenario)
    responses_df = serialise(responses["responses"]).reset_index(drop=True)

    concat = pd.concat([scenario, responses_df], axis=1).reset_index(drop=True)
    output.append(concat)
# Out:
# 81:
# 	gpt: According to Karen, Bea believes that Karen bought some chocolate cake.
# 	gpt: Karen believes that Bea believes she bought some chocolate cake because Bea was not present when Bruce informed her about the available options at the bazaar. Therefore, Karen assumes that Bea is still under the impression that chocolate cake is available.
# 	gpt: Bea believes that Karen bought some honey buns.
# 	gpt: No, Karen does not know that Bruce told Bea that there isn't any chocolate cake at the bazaar.
# 	gpt: Karen bought some cinnamon cookies from the bazaar.
# 	gpt: Bruce believes that honey buns are being sold at the bazaar.
# 82:
# 	gpt: Ece Selin'in ballı çörek satın aldığına inanıyor.
# 	gpt: Selin, Ece'nin kermeste sadece ballı çörek olduğunu öğrendiğini ve Selin'in kermese çikolatalı kek almak için gittiğini söylediğini biliyor. Bu nedenle Selin, Ece'nin bu bilgilere dayanarak Selin'in ballı çörek satın aldığına inandığını düşünüyor.
# 	gpt: Ece, Selin'in kermesten çikolatalı kek satın aldığına inanıyor.
# 	gpt: Hayır, Selin Okan'ın Ece'ye kermeste çikolatalı kek olmadığını söylediğini bilmiyor. Selin, Ece'ye kermeste çikolatalı kek alacağını söyledikten sonra sınıftan ayrılıyor ve sonrasında Okan gelip Ece'ye kermeste sadece ballı çörek olduğunu söylüyor. Selin bu bilgiye sahip değil, bu yüzden Ece'nin Okan'ın söylediklerini bilmediğini varsayabiliriz.
# 	gpt: Selin kermesten tarçınlı kurabiye aldı.
# 	gpt: Okan kermeste sadece ballı çörek satıldığına inanıyor.
# 84:
# 	gpt: Rebecca thinks that her mother got her a cat for her birthday.
# 	gpt: Rebecca thinks so because she heard a sound coming from the cupboard, and when she opened it, she saw a cat hidden inside a box. She believes that her mother got her the cat as a surprise birthday gift.
# 	gpt: Rebecca’s mother got Rebecca a toy for her birthday.
# 	gpt: According to Rebecca's mother, Rebecca thinks that she will get a cat for her birthday.
# 	gpt: Based on the given information, it is not explicitly mentioned whether Rebecca's mother knows that Rebecca saw the cat.
# 	gpt: Rebecca's father, upon seeing the cat in the kitchen, thinks that their neighbor's cat has entered their kitchen and takes it back to their neighbor.
# 85:
# 	gpt: Melis, annesinin ona doğum günü hediyesi olarak bir oyuncak aldığını düşünüyor.
# 	gpt: Melis, dolaptan gelen sesi duyduğunda dolabı açtığında bir kutu içinde saklanan bir kedi görmüştü. Bu nedenle, annesinin aslında ona bir oyuncak yerine bir kedi aldığını düşünmüştü.
# 	gpt: Melis'in annesi doğum günü için ona bir oyuncak aldı.
# 	gpt: Melis'in annesine göre, Melis doğum günü hediyesi olarak bir oyuncak alacağını düşünüyor.
# 	gpt: Hayır, Melis'in annesi Melis'in kediyi gördüğünü bilmiyor. Melis, kediyi dolaptan çıkardıktan sonra annesi okula gitmek için hazırlanırken mutfakta değildi. Dolayısıyla, annesi henüz kediyi görmemiş olabilir.
# 	gpt: Melis'in babası, kediyi mutfakta bulduğunda komşularının kedisinin kaçıp mutfaklarına girdiğini düşünüyor. Bu nedenle, kediyi alıp komşularına götürmeye karar veriyor. Babası, sürpriz doğum günü hediyesinden haberi olmadığı için kediyi Melis'in annesinin aldığını düşünmüyor.
# 87:
# 	gpt: Dwight believes that Jane will look for the pie inside of the cupboard.
# 	gpt: Dwight believes that Jane will look for the pie inside of the cupboard because that is where she originally put it before leaving the room.
# 	gpt: Yes, Jane knows that Dwight put the pie in the basket because she saw him do it through the window.
# 	gpt: No, Dwight does not know that Jane saw him put the pie in the basket.
# 	gpt: The pie is actually in the drawer.
# 	gpt: Jane believes that the pie is in the cupboard.
# 	gpt: Jane will look for the pie in the cupboard.
# 	gpt: Dwight believes that the pie is in the basket.
# 88:
# 	gpt: Burak, Nihal'in turtayı aramak için dolaba bakacağına inanıyor.
# 	gpt: Burak, Nihal'in turtayı dolaba koyduğunu gördüğü için onun dolaba bakacağını düşünüyor.
# 	gpt: Hayır, Nihal Burak'ın turtayı sepete koyduğunu bilmiyor. Nihal sadece Burak'ın turtayı dolaptan alıp yerini değiştirdiğini görmüş, ancak turtanın sonradan sepete konulduğunu görmemiştir.
# 	gpt: Hayır, Burak Nihal'in turtayı sepete koyarken onu gördüğünü bilmiyor. Burak sadece turtanın yerini değiştirdiğini düşünüyor.
# 	gpt: Turta aslında çekmece içinde bulunmaktadır.
# 	gpt: Nihal turtanın dolapta olduğuna inanıyor.
# 	gpt: Nihal turtayı dolapta arayacak.
# 	gpt: Burak turtanın sepet içinde olduğuna inanıyor.
# 90:
# 	gpt: John thinks that Catherine went to the shopping mall to buy some balloons.
# 	gpt: John thinks that Catherine went to the shopping mall because he overheard the balloon man mentioning that there was an activity happening there.
# 	gpt: No, John does not know that the balloon man told Catherine where he would be going.
# 	gpt: The balloon man is at the shopping mall.
# 	gpt: Catherine thinks that the balloon man is at the school.
# 	gpt: Catherine will look for the balloon man at the school.
# 	gpt: John thinks that the balloon man is at the park.

# %%
len(output)
# Out:
# 7

# %%
df = pd.concat(output, axis="index", ignore_index=True).reset_index(drop=True)

# %%
df.to_csv("../output/extra.csv")
